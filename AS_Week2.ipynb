# %% [markdown]
# <a href="https://colab.research.google.com/github/hohohoo07/Advanced_software_Lab./blob/main/AS_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
image = cv2.imread('soccer.jpg')
print(image.shape)
# Out:
# (948, 1434, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('soccer.jpg')
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_image)
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)
plt.axis('off')
plt.show()

# %%
b, g, r = cv2.split(image)

# %%
merged = cv2.merge([b, g, r])

# %%
plt.imshow(merged)
plt.axis('off')
plt.show()

# %%
merged_wrong = cv2.merge([r, g, b])

# %%
plt.imshow(merged_wrong)
plt.axis('off')
plt.show()

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(hsv)

# %%
plt.imshow(hsv)
plt.axis('off')
plt.show()

# %%
# import numpy as np
# lower_blue = np.array([100, 100, 50])
# upper_blue = np.array([130, 255, 255])

# mask = cv2.inRange(hsv, lower_blue, upper_blue)

# %%
import numpy as np
lower_blue = np.array([100, 100, 50])
upper_blue = np.array([130, 255, 255])
mask = cv2.inRange(hsv, lower_blue, upper_blue)
result = cv2.bitwise_and(image, image, mask=mask)
plt.imshow(result)
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('soccer.jpg')
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

lower_blue = np.array([100, 100, 50])
upper_blue = np.array([130, 255, 255])
mask = cv2.inRange(hsv, lower_blue, upper_blue)

result = cv2.bitwise_and(image, image, mask=mask)
result_rgb = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result_rgb)
plt.axis('off')
plt.show()

# %%
cv2.imwrite('gray_image.png', gray)
cv2.imwrite('mask.png', mask)
success = cv2.imwrite('blue_result.png', result)

print(success)
# Out:
# True
